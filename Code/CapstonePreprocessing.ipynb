# %%
from basic_image_eda import BasicImageEDA

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-449f9db5-7e86-4e7a-880d-4571fb288d85" name="files[]" multiple disabled />
#      <output id="result-449f9db5-7e86-4e7a-880d-4571fb288d85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
if __name__ == "__main__":  # for multiprocessing
    data_dir = uploaded

    # below are default values.
    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = False
    nonzero = False

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40ef6514d2e7> in <module>()
#       1 if __name__ == "__main__":  # for multiprocessing
# ----> 2     data_dir = uploaded
#       3
#       4     # below are default values.
#       5     extensions = ['png', 'jpg', 'jpeg']
#
# NameError: name 'uploaded' is not defined

# %%
from google.colab import files
uploaded_imgs = files.upload()
# Out:
#      <input type="file" id="files-860c6a54-d194-4071-ae21-21099eabf794" name="files[]" multiple disabled />
#      <output id="result-860c6a54-d194-4071-ae21-21099eabf794">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Places365_test_00000012.jpg to Places365_test_00000012 (1).jpg
# Saving Places365_test_00000021.jpg to Places365_test_00000021.jpg
# Saving Places365_test_00000025.jpg to Places365_test_00000025.jpg

# %%
print(len(uploaded_imgs))
# Out:
# 3

# %%
print(type(uploaded_imgs))
# Out:
# <class 'dict'>

# %%
for key, value in uploaded_imgs.items():
    print(uploaded_imgs)
# Out:
# {'Places365_test_00000012.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01\xe0\x02\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc
# ...

# %%
for img in uploaded_imgs:
  print(img)
# Out:
# Places365_test_00000012.jpg
# Places365_test_00000021.jpg
# Places365_test_00000025.jpg

# %%
# !pip install basic-image-eda

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e561ff1001f2> in <module>()
#      12     nonzero = False
#      13
# ---> 14     BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero)
#
# /usr/local/lib/python3.6/dist-packages/basic_image_eda/eda.py in explore(cls, data_dir, extensions, threads, dimension_plot, channel_hist, nonzero)
#     111         start = time.time()
#     112
# --> 113         img_paths = cls.get_img_paths(data_dir, extensions)
#     114         if len(img_paths) == 0:
#     115             print('No images found.')
#
# /usr/local/lib/python3.6/dist-packages/basic_image_eda/eda.py in get_img_paths(data_dir, extensions)
#      29         img_paths = []
#      30         for extension in extensions:
# ...

# %%
uploaded_imgs_2 = files.upload()
# Out:
#      <input type="file" id="files-1adf56ef-47de-4f5c-9ee9-03e4a1fbb434" name="files[]" multiple disabled />
#      <output id="result-1adf56ef-47de-4f5c-9ee9-03e4a1fbb434">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
data_path = '/content/drive/My Drive/cleaned_data'

# %%
import os

# %%
images_list = list()

for root, dirs, files in os.walk(data_path):
    for file in files:
      images_list.append(file)

# %%
print(len(images_list))
# Out:
# 9929

# %%
for img in images_list:
  print(img)
  break
# Out:
# Places365_test_00317843.jpg

# %%
from basic_image_eda import BasicImageEDA

if __name__ == "__main__":  # for multiprocessing

    data_dir = data_path

    # below are default values. 
    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = False
    nonzero = False

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero)
# Out:
# found 9929 images.
#   0%|          | 0/9929 [00:00<?, ?it/s]
# Using 2 threads.
# 100%|██████████| 9929/9929 [1:30:43<00:00,  1.67it/s]
# *--------------------------------------------------------------------------------------*
# number of images          |  9929
#
# dtype                     |  uint8
# channels                  |  [1, 3]
# extensions                |  ['peg', 'jpg']
#
# min height                |  225
# mean height               |  540.0539832812972
# max height                |  1017
#
# min width                 |  225
# mean width                |  688.5998589988922
# max width                 |  3360
#
# mean height/width ratio   |  0.7842783820293608
# recommended input size    |  [544 688] (h x w, multiples of 8)
# recommended input size    |  [544 688] (h x w, multiples of 16)
# recommended input size    |  [544 704] (h x w, multiples of 32)
#
# channel mean(0~1)         |  [0.46080861 0.48234877 0.45729311]
# ...
